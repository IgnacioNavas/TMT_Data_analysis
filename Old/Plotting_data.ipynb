# %% [markdown]
# # Ploting Data
# To imporove the reading of the code the functions used for plotting are in the file [Plotting_functions.py](./utils.py)

# %%
import warnings

import numpy as np

from utils import *

# %%
# df_1_HME1 = pd.read_excel("Experiment/hme1_1/Data/Processed/Handmade_Log2_FC_from_FGZC.xlsx")
df_2_HME1 = pd.read_excel('Experiment/hme1_2/Data/Processed/full_starve_continuous_FC_nrep_SD.tsv', sep ='\t' )
# df_HEK = pd.read_excel('Experiment/hek_1/Data/Processed/full_starve_continuous_FC_nrep_SD.xlsx')
# df.drop(["n_reps"], inplace=True, axis=1)
# df_hTERT = pd.read_excel("Experiment/hme1_1/Data/Processed/Handmade_Log2_FC_from_FGZC.xlsx")

# %%
INSR_reactome = pd.read_csv("External_Data/Reactome/InsR_signaling_proteins_reactome.tsv", sep='\t')
EGFR_reactome = pd.read_csv("External_Data/Reactome/EGFR_signaling_proteins_reactome.tsv", sep='\t')
mTOR_reactome = pd.read_csv("External_Data/Reactome/mTOR_signaling_reactome.tsv", sep='\t')
RTK_signaling = pd.read_csv("External_Data/Reactome/RTK_signaling_proteins_reactome.tsv", sep='\t')
RAF_indep = pd.read_csv("External_Data/Reactome/RAF_independent_MAPK1_3_activation_reactome.tsv", sep='\t')
starvation = pd.read_csv("External_Data/Reactome/Starvation_response_reactome.tsv", sep='\t')

INSR_list = INSR_reactome.Identifier.values.tolist()
EGRF_list = EGFR_reactome.Identifier.values.tolist()
mTOR_list = mTOR_reactome.Identifier.values.tolist()
RTK_list = RTK_signaling.Identifier.values.tolist()
RAF_indep_list = RAF_indep.Identifier.values.tolist()
starvation_list = starvation.Identifier.values.tolist()

# common = np.intersect1d(INSR_list, EGRF_list)
common = np.intersect1d(starvation_list, EGRF_list)

print(len(starvation_list),len(EGRF_list), len(common))

# %%
warnings.filterwarnings('ignore')
# 'EGFR', 'AKT2', 'P27361', 'Q92888', 'AHNAK2'
plot_protein_phosphosites_small(df= df_2_HME1, proteins= ['GAB1'],
                          x_axis= ['Full', 'Starve', '2', '5', '10', '15', '90'],
                          legend = ['1.57 nM EGF', '100 nM INS', '1.57 nM EGF + 100 nM INS'],#['1.57 nM EGF', '100 nM INS', '1.57 nM EGF + 100 nM INS'] ['4.7 nM EGF', '10 nM INS', '4.7 nM EGF + 10 nM INS']
                          saving_path = "Experiment/hme1_2/Results/Interesting_proteins",
                          plot_individually = False,
                          saving_info = "", title_info="",
                          save_pdf = False,
                          save_png = False, plot_close = False, fit_y_lims = False)

# %%
warnings.filterwarnings('ignore')
prot_list = ["DUSP6"]

plot_protein_phosphosites_small(df= df_1_HME1, proteins= prot_list, 
                          x_axis= ['Full', 'Starve', '1',  '2', '5', '10','90'],
                          legend = ['4.7 nM EGF', '10 nM INS', '4.7 nM EGF + 10 nM INS'],#['1.57 nM EGF', '100 nM INS', '1.57 nM EGF + 100 nM INS'] 
                          saving_path = "Experiment/hme1_2/Results/Interesting_proteins",
                          plot_individually = False,
                          saving_info = "", title_info="hme1_1",
                          save_pdf = False,
                          save_png = False, plot_close = False, fit_y_lims = False) 

plot_protein_phosphosites_small(df= df_2_HME1, proteins= prot_list, 
                          x_axis= ['Full', 'Starve', '2', '5', '10', '15', '90'],
                          legend = ['1.57 nM EGF', '100 nM INS', '1.57 nM EGF + 100 nM INS'],#['1.57 nM EGF', '100 nM INS', '1.57 nM EGF + 100 nM INS'] ['4.7 nM EGF', '10 nM INS', '4.7 nM EGF + 10 nM INS']
                          saving_path = "Experiment/hme1_2/Results/Interesting_proteins",
                          plot_individually = False,
                          saving_info = "", title_info="hme1_2",
                          save_pdf = False,
                          save_png = False, plot_close = False, fit_y_lims = False) 

plot_protein_phosphosites_small(df= df_HEK, proteins= prot_list, 
                          x_axis= ['Full', 'Starve', '2', '5', '10', '15', '90'],
                          legend = ['1.57 nM EGF', '100 nM INS', '1.57 nM EGF + 100 nM INS'],#['1.57 nM EGF', '100 nM INS', '1.57 nM EGF + 100 nM INS'] ['4.7 nM EGF', '10 nM INS', '4.7 nM EGF + 10 nM INS']
                          saving_path = "Experiment/hme1_2/Results/Interesting_proteins",
                          plot_individually = False,
                          saving_info = "", title_info="hek_1",
                          save_pdf = False,
                          save_png = False, plot_close = False, fit_y_lims = False)

# %%
#DATA PREPARATION IN CASE OF WNTING TO PLOT SPECIFIC CLUSTERS
clustered_df = pd.read_excel("Experiment/hme1_1/Results/Clusters/Cluster7/clustering_81.xlsx")
# clustered_df.drop(["Unnamed: 0"],axis=1, inplace=True)
# clustered_df.to_excel("Experiment/hme1_1/Results/Clusters/Cluster7/clustering_81.xlsx", index=False)
clustered_df = clustered_df.loc[clustered_df['protein_ID'] == "Q92888"]
clustered_df

# %%
cluster_46 = clustered_df.loc[clustered_df['Clusters'] == 46]
cluster_46.drop(["Clusters"], axis=1, inplace=True)
cluster_46.fillna(value=0, inplace=True)

cluster_46

# %%
warnings.filterwarnings('ignore')
df = pd.read_excel("Experiment/hme1_1/Results/tslearn_Clusters/25_clusters/1_hTERT_HME1_Full_dataset_25_clusters.xlsx")

plot_dataset_phosphosites(df=df, cluster = "3",
                          legend = ['4.68 nM EGF', '10 nM INS', '4.68 nM EGF+ 10 nM INS'], x_axis=['Full', 'Starve', '1', '2', '5', '10', '90'], color_palette = ['r', 'b', 'fuchsia'],
                          saving_path = "Experiment/hme1_1/Results/Clusters/Cluster7", dataset_name= "", saving_info="",
                          plot_individually = False, fit_y_lims=False,  plot_close=False,
                          save_pdf=False, save_png=False)

# %%
df_1_HME1 = pd.read_excel("Experiment/hme1_1/Results/tslearn_Clusters/25_clusters/1_hTERT_HME1_Full_dataset_25_clusters.xlsx")
df_2_HME1 = pd.read_excel("Experiment/hme1_2/Results/tslearn_Clusters/25_clusters/2_hTERT_HME1_Full_dataset_25_clusters.xlsx")
df_1_HEK = pd.read_excel("Experiment/hek_1/Results/tslearn_Clusters/25_clusters/1_HEK293T_Full_dataset_25_clusters.xlsx")

# %%
warnings.filterwarnings('ignore')

clusters_plot(df=df_1_HEK,
              legend=['1.57 nM EGF', '100 nM Ins', '1.57 nM EGF + 100 nM Ins'],
              saving_path="../notebooks/04_visualization/", cluster_name ="hek_1",
              saving_info="hek_1",
              save_pdf=False, save_png=True, plot_close=False, fit_y_lims=False)

# %% [markdown]
# ["Q9H8S9", "Q7L9L4", "Q70IA8", "P46937", "Q16635", "O00750", "Q13043", "Q10325", "O54748", "O95835", "Q9NRM7"]
#
# temporal regulation of EGF signaling networks by the scaffold protein Shc1: ["Q13191", "Q07889", "Q07890", "P00533", "P04626", "P21860", "Q9UQC2", "Q13480", "Q06124", "P62993", "Q9UJM3", "P42336", "P27986", "O00459", "Q38SD2", "Q9H706", "Q12774", "Q05209", "O15357", "P53680", "O94973",  "Q5VWQ8", "Q9H792", "P62136", "P36873", "Q9UJF2", "O43150", "Q86YV5", "Q8NEM2"]

# %% [markdown]
# ## Plotting external data.
# ### P146 A Phosphoproteomics Data Resource for Systems-level Modeling of Kinase Signaling Networks
#
# data

# %%
# Load the dataframe independently so it has not to be loaded each time we want to plot a set of proteins
path_p146 = "External_Data/P146_Feng_Song_phospho_proteomics_data/Data/timecourse_FC_data.xlsx"
data_frame_p146 = pd.read_excel(path_p146)
data_frame_p146

# %%
def plot_protein_phosphosites_together_p146(df, proteins=list, legend=list, path=str, saving_path=str,
                                            saving_info="", save_pdf=False, save_png=False, plot_close=False,
                                            fit_y_lims=False):
    '''Plot to PDF ALL phosphosites of a protein together in one single plot. "y" limits are ajusted to the limits of each phosphosites'''
    # Check the saving folder exists
    saving_folder = re.sub("/Data/.*", f"/{saving_path}", path)
    if not os.path.exists(saving_folder):
        print("Creating saving folder")
        os.makedirs(saving_folder)

    for protein in proteins:

        # Create sub-dataframe with only the protein we are interested in. If the protein doesn't exist in the dataframe skip code
        if protein in df['protein_ID'].to_list():
            sub_df = df.loc[df['protein_ID'] == protein].copy()
            print(f"Ploting sites of protein {protein}")
        else:
            print(f"The protein {protein} is not present in the dataset")
            continue
        # Check if a folder for the desired protein exists. If no, create one
        if protein in os.listdir(saving_folder):
            pass
        else:
            new_path = f"{saving_folder}/{protein}"
            print(f"Createating saving folder for {protein}")
            os.makedirs(new_path)

        # sub_df.sort_values(by=['site'], inplace=True)

        # Geting some basic information and parameters for the plots
        number_phos = len(sub_df)
        sqrt_n_p = int(np.ceil(np.sqrt(number_phos)))
        if sqrt_n_p <= 2:
            empty_plots = 0
        else:
            empty_plots = (sqrt_n_p * sqrt_n_p) - number_phos
        # print(number_phos, sqrt_n_p, empty_plots)

        # If the protein only has one phosphosite the code cannot make a plot with one subplot, so I'll have to make it individually
        # single_phsite_proteins = []
        # if number_phos == 1:
        #     single_phsite_proteins.append(protein)
        #     print(f"Protein {protein} has only one phosphosite. Plot it individually")
        #     continue

        # Avoid getting rows with empty plots
        if empty_plots >= sqrt_n_p:
            sqrt_n_p_X = sqrt_n_p - 1
        else:
            sqrt_n_p_X = sqrt_n_p

        # Decide wether to fit the y axes or not
        if fit_y_lims == True:  # Fit "y" limits for each phosphosite
            y_fixed = "_y_axis_fixed"
        elif type(fit_y_lims) == list:
            y_lim_min = fit_y_lims[0]
            y_lim_max = fit_y_lims[1]
            y_fixed = f"_y_axis_fixed_{y_lim_min}_{y_lim_max}"
        else:  # Fit the same "y" limit for all phosphosites
            sub_values_df = sub_df.iloc[:, 4:9]
            y_lim_max = (sub_values_df.max().max()) * 1.1
            y_lim_min = (sub_values_df.min().min()) * 1.1
            if y_lim_min > 0:
                y_lim_min = -1 * y_lim_min
            y_fixed = "_y_axis_general"

        k = 0  # Counter to stop ploting when there is no more phosphosites

        # Seting subplots aprameters
        fig, ax = plt.subplots(sqrt_n_p, sqrt_n_p_X,figsize=(18, 13))  # figsize=(7, 4) figsize=(18, 13) figsize=(29.7, 21)
        fig.tight_layout(w_pad=1.75, h_pad=3)
        plt.subplots_adjust(top=0.94)  # percentage of the figure that the plots are using

        # Go through the sub_df to plot all the phosphosites
        for i in range(sqrt_n_p):  # y
            for j in range(sqrt_n_p_X):  # X
                if k == number_phos:  # Stop plotting, all phosphorylation sites have been plotted
                    continue
                else:
                    # IN THIS CASE I AM ACCESSING THE ROW BY INDEXING,
                    # that's why the "id" is alreay at possition 0 and all the indexing is shifted compared to the datafram by -1
                    row = sub_df.iloc[k,:]  # Go through the rows of the subdataset with the phsophosites for the protein
                    # Collect identification data of the phosphorylatio site
                    site = row[2] #2
                    name = row[1] #1
                    id = row[0] #0

                    # Collect data of the time points of the phosphosites
                    EGF = row[3:8]

                    # Collect data of the standard deviation of each timepoint
                    EGF_sd = row[8:]

                    ax[i, j].errorbar(x=['Controll', '2', '4', '8', '12'], y=EGF, yerr=EGF_sd,
                                      marker='o', color='r', capsize=4, elinewidth=1.3)

                        # Subplot parameters
                    ax[i, j].set_title(f"{site}")  # , weight='bold'  INCLUDE THE POSIBILITY OF ADDING THE PHOSPHOSITE SEQUENCE
                    ax[i, j].set_xlabel("Time (min)")
                    ax[i, j].set_ylabel("Log2FC")
                    ax[i, j].grid()

                    # Using specific limits
                    if fit_y_lims == True:
                        min_y = min(EGF)* 1.1 
                        max_y = max(EGF)* 1.1
                        if min_y > 0:
                            min_y = -1 * min_y
                        ax[i, j].set_ylim(min_y, max_y)
                    else:  # Using general limits
                        ax[i, j].set_ylim(y_lim_min, y_lim_max)
                    ax[i, j].set_xlim(-1, 5)

                    # count the phosphorylation site as plotted
                    k = k + 1

        # General parameters of the plot
        fig.legend(labels=legend, loc="upper right") # ncol=len(groups
        fig.suptitle(f"{name}_{id} {date.today()}", weight='bold')

        # Saving the plot
        if save_pdf == True:
            plt.savefig(f"{saving_folder}/{protein}/{name}_{id}_0_All{y_fixed}{saving_info}.pdf")
            print(f"{name}_{id}_0_All{y_fixed}{saving_info}.pdf Plot saved as PDF")
        else:
            print(f"{protein} Plot not saved")
        if save_png == True:
            plt.savefig(f"{saving_folder}/{protein}/{name}_{id}_0_All{y_fixed}{saving_info}.png")
            print(f"{saving_folder}/{protein}/{name}_{id}_0_All{y_fixed}{saving_info}.png Plot saved as PNG")
        if plot_close == True:
            plt.close()

# %%
plot_protein_phosphosites_together_p146(df= data_frame_p146, proteins= ["Q9H706"], #A0FGR8 P28482
                                        legend = ['X nM EGF'], 
                                        path= path_p146, 
                                        saving_path = "Results/Interesting_proteins", 
                                        saving_info = "_Log2_FC", save_pdf = True,
                                        save_png = True, plot_close = False, fit_y_lims = False) 
#
