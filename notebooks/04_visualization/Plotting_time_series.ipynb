# %% [markdown]
# # Plotting MS/MS data

# %%
from src.column_spec import *
from src.plotting_functions import *

# %%
hme1_1 = pd.read_csv("../../Experiment/1_hTERT_HME1/Data/Processed/20260505_hTERT_HME1_1_processes_phosphoPlus.tsv", sep="\t")
hme1_2 = pd.read_csv("../../Experiment/2_hTERT_HME1/Data/Processed/20260505_hTERT_HEM1_2_processes_phosphoPlus.tsv", sep="\t")
hek_1 = pd.read_csv("../../Experiment/1_HEK293T/Data/Processed/20260505_HEK293T_raw_selection_processes_phosphoPlus.tsv", sep="\t")
hme1_mutants = pd.read_csv("../../Experiment/3_hTERT_HME1_mutants_comparison/Data/Processed/20260505_hTERT_HME1_mutants_test_processed_phosphoPlus_filtered.tsv", sep="\t")

# %% [markdown]
# ## Plot time serie

# %%
plot_protein_phosphosites(hme1_2,
                          data_type="log2:FC",
                          proteins=["EGFR"],
                          cell_lines=["WT"],
                          conditions=['_EGF_', '_INS_', '_EGFnINS_'],
                          legend_plot=['EGF', 'INS', 'EGF + INS'],
                          color_palette={"_EGF_": "red",
                                         "_INS_": "blue",
                                         "_EGFnINS_": "fuchsia"},
                          saving_path="",
                          saving_info="",
                          title_info="",
                          fit_y_lims=False,
                          one_figure_per_site=False,
                          plot_close=False,
                          save_pdf=False,
                          save_png=False,
                          )

# %% [markdown]
# ## Plot dataset phosphosites

# %%
df = hme1_2.loc[hme1_2["protein_name"] == "GAB1"]

# %%
plot_dataset_phosphosites(df,
                          cluster_column="",
                          cluster_number=None,
                          data_type="log2:FC",
                          cell_lines=["WT"],
                          conditions=["_EGF_", "_INS_", "_EGFnINS_"],
                          legend_plot=["_EGF_", "_INS_", "_EGFnINS_"],
                          color_palette={"_EGF_": "red",
                                         "_INS_": "blue",
                                         "_EGFnINS_": "fuchsia"},
                          saving_path="",
                          dataset_name="",
                          saving_info="",
                          title_info="",
                          fit_y_lims=False,
                          one_figure_per_site=False,
                          plot_close=False,
                          save_pdf=False,
                          save_png=False)

# %% [markdown]
# ## Plot protein profile

# %%
plot_protein_profile(hek_1,
                     proteins = ["EGFR", "GAB1"],
                     cell_lines = ["WT"],
                     data_type="log2:FC",
                     conditions=["_EGF_", "_INS_", "_EGFnINS_"],
                     saving_path="",
                     saving_info="",
                     legend=False,
                     save_pdf=False,
                     save_png=False)

# %% [markdown]
# ## Volcano Plot

# %%
print(hme1_1.columns.values)

# %%
plot_volcano(hme1_2,
             fc_col = "WT_log2:FC_EGF_10",
             pval_col = "WT_log2:FDR_EGF_10",
             fc_thresh=0.50,
             pval_thresh=0.05,
             precomputed=False,
             title=None,
             ax=None,
             highlight_proteins=['EGFR', 'GAB1', 'BRAF'],
             match_cols=("protein_Id", "protein_name"),
             case_insensitive=True,
             fit_x_limit=False)

# %%
plot_volcano_interactive(hme1_2,
                         fc_col = "WT_log2:FC_EGF_10",
                         pval_col = "WT_log2:adjustedFDR_EGF_10",
                         site_col="site",
                         fc_thresh=0.50,
                         pval_thresh=0.05,
                         precomputed=True,
                         title=None,
                         highlight_proteins=['GAB1'],
                         match_cols=("protein_Id", "protein_name"),
                         case_insensitive=True,
                         show_highlight_labels=False)
