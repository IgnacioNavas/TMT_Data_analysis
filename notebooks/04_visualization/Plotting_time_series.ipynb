# %% [markdown]
# # Plotting MS/MS data

# %%
from src.column_spec import *
from src.plotting_functions import *

# %%
hme1_1 = pd.read_csv("../../Experiment/hme1_1/Data/Processed/20260505_hTERT_HME1_1_processes_phosphoPlus.tsv", sep="\t")
hme1_2 = pd.read_csv("../../Experiment/hme1_2/Data/Processed/20260505_hTERT_HEM1_2_processes_phosphoPlus.tsv", sep="\t")
hek_1 = pd.read_csv("../../Experiment/hek_1/Data/Processed/20260505_HEK293T_raw_selection_processes_phosphoPlus.tsv", sep="\t")
# hme1_mutants = pd.read_csv("../../Experiment/hme1_mutants_test/Data/Processed/20260505_hTERT_HME1_mutants_test_processed_phosphoPlus_filtered.tsv", sep="\t")

# %%
hme1_mutants.loc[hme1_mutants["protein_name"] == "MAPK3"]#[["protein_Id", "site_start", "site_end", "n_localized", "STY_localized", "sty_positions", "site_index", "site"]]
# Out:
#        protein_Id protein_name                         description  \
# 38879      P27361        MAPK3  Mitogen-activated protein kinase 3
# 38880      P27361        MAPK3  Mitogen-activated protein kinase 3
# 56429      P27361        MAPK3  Mitogen-activated protein kinase 3
# 56430      P27361        MAPK3  Mitogen-activated protein kinase 3
# 56431      P27361        MAPK3  Mitogen-activated protein kinase 3
# 56432      P27361        MAPK3  Mitogen-activated protein kinase 3
# 56433      P27361        MAPK3  Mitogen-activated protein kinase 3
# 56434      P27361        MAPK3  Mitogen-activated protein kinase 3
# 56435      P27361        MAPK3  Mitogen-activated protein kinase 3
# 56436      P27361        MAPK3  Mitogen-activated protein kinase 3
# 56437      P27361        MAPK3  Mitogen-activated protein kinase 3
# 56438      P27361        MAPK3  Mitogen-activated protein kinase 3
# 78803      P27361        MAPK3  Mitogen-activated protein kinase 3
# 100873     P27361        MAPK3  Mitogen-activated protein kinase 3
# 147277     P27361        MAPK3  Mitogen-activated protein kinase 3
# 170894     P27361        MAPK3  Mitogen-activated protein kinase 3
# 170895     P27361        MAPK3  Mitogen-activated protein kinase 3
#
#                 peptide_sequence                      modified_sequence  \
# 38879                 FRHENVIGIR                             FRHENVIGIR
# 38880             FRHENVIGIRDILR                         FRHENVIGIRDILR
# 56429        IADPEHDHTGFLTEYVATR                    IADPEHDHTGFLTEYVATR
# 56430        IADPEHDHTGFLTEYVATR           IADPEHDHTGFLTEYVAT[79.9663]R
# 56431        IADPEHDHTGFLTEYVATR           IADPEHDHTGFLTEY[79.9663]VATR
# 56432        IADPEHDHTGFLTEYVATR           IADPEHDHTGFLT[79.9663]EYVATR
# 56433        IADPEHDHTGFLTEYVATR  IADPEHDHTGFLT[79.9663]EYVAT[79.9663]R
# 56434        IADPEHDHTGFLTEYVATR  IADPEHDHTGFLT[79.9663]EY[79.9663]VATR
# 56435        IADPEHDHTGFLTEYVATR           IADPEHDHT[79.9663]GFLTEYVATR
# 56436        IADPEHDHTGFLTEYVATR  IADPEHDHT[79.9663]GFLTEYVAT[79.9663]R
# 56437        IADPEHDHTGFLTEYVATR  IADPEHDHT[79.9663]GFLTEY[79.9663]VATR
# 56438        IADPEHDHTGFLTEYVATR  IADPEHDHT[79.9663]GFLT[79.9663]EYVATR
# 78803                LKELIFQETAR                            LKELIFQETAR
# 100873                 NYLQSLPSK                              NYLQSLPSK
# 147277                TLREIQILLR                             TLREIQILLR
# 170894   YTQLQYIGEGAYGMVSSAYDHVR                YTQLQYIGEGAYGMVSSAYDHVR
# 170895  YTQLQYIGEGAYGMVSSAYDHVRK               YTQLQYIGEGAYGMVSSAYDHVRK
#
#         site_start  site_end  peptide_length charges  \
# 38879           95       104              10       3
# 38880           95       108              14       4
# 56429          190       208              19   2,3,4
# 56430          190       208              19       2
# 56431          190       208              19     2,3
# 56432          190       208              19     2,3
# 56433          190       208              19     2,3
# 56434          190       208              19     2,3
# 56435          190       208              19       2
# 56436          190       208              19       2
# 56437          190       208              19       2
# 56438          190       208              19       2
# 78803          360       370              11     2,3
# 100873         279       287               9       2
# 147277          85        94              10       3
# 170894          42        64              23     2,3
# 170895          42        65              24       4
#
#            assigned_modifications  ...  GAB1Y259A_log2:adjustedFDR_EGF_2  \
# 38879                         NaN  ...                               NaN
# 38880                         NaN  ...                               NaN
# 56429                         NaN  ...                               NaN
# 56430                18T(79.9663)  ...                               NaN
# 56431                15Y(79.9663)  ...                               NaN
# 56432                13T(79.9663)  ...                               NaN
# 56433   13T(79.9663),18T(79.9663)  ...                               NaN
# 56434   13T(79.9663),15Y(79.9663)  ...                               NaN
# 56435                 9T(79.9663)  ...                               NaN
# 56436    18T(79.9663),9T(79.9663)  ...                               NaN
# 56437    15Y(79.9663),9T(79.9663)  ...                               NaN
# 56438    13T(79.9663),9T(79.9663)  ...                               NaN
# 78803                         NaN  ...                               NaN
# 100873                        NaN  ...                               NaN
# 147277                        NaN  ...                               NaN
# 170894                        NaN  ...                               NaN
# 170895                        NaN  ...                               NaN
#
#         GAB1Y259A_log2:adjustedFDR_EGF_10  GAB1Y259A_log2:adjustedFDR_EGF_25  \
# 38879                                 NaN                                NaN
# 38880                                 NaN                                NaN
# 56429                                 NaN                                NaN
# 56430                                 NaN                                NaN
# 56431                                 NaN                                NaN
# 56432                                 NaN                                NaN
# 56433                                 NaN                                NaN
# 56434                                 NaN                                NaN
# 56435                                 NaN                                NaN
# 56436                                 NaN                                NaN
# 56437                                 NaN                                NaN
# 56438                                 NaN                                NaN
# 78803                                 NaN                                NaN
# 100873                                NaN                                NaN
# 147277                                NaN                                NaN
# 170894                                NaN                                NaN
# 170895                                NaN                                NaN
#
#         functional_score  ERK_motif  ORGANISM  ON_FUNCTION  ON_PROCESS  \
# 38879                NaN        NaN       NaN          NaN         NaN
# 38880                NaN        NaN       NaN          NaN         NaN
# 56429                NaN        NaN       NaN          NaN         NaN
# 56430           0.702641        NaN       NaN          NaN         NaN
# 56431           0.985552        NaN       NaN          NaN         NaN
# 56432           0.990935        NaN       NaN          NaN         NaN
# 56433           0.846788        NaN       NaN          NaN         NaN
# 56434           0.988243        NaN       NaN          NaN         NaN
# 56435           0.325123        NaN       NaN          NaN         NaN
# 56436           0.513882        NaN       NaN          NaN         NaN
# 56437           0.655337        NaN       NaN          NaN         NaN
# 56438           0.658029        NaN       NaN          NaN         NaN
# 78803                NaN        NaN       NaN          NaN         NaN
# 100873               NaN        NaN       NaN          NaN         NaN
# 147277               NaN        NaN       NaN          NaN         NaN
# 170894               NaN        NaN       NaN          NaN         NaN
# 170895               NaN        NaN       NaN          NaN         NaN
#
#         ON_PROT_INTERACT  ON_OTHER_INTERACT
# 38879                NaN                NaN
# 38880                NaN                NaN
# 56429                NaN                NaN
# 56430                NaN                NaN
# 56431                NaN                NaN
# 56432                NaN                NaN
# 56433                NaN                NaN
# 56434                NaN                NaN
# 56435                NaN                NaN
# 56436                NaN                NaN
# 56437                NaN                NaN
# 56438                NaN                NaN
# 78803                NaN                NaN
# 100873               NaN                NaN
# 147277               NaN                NaN
# 170894               NaN                NaN
# 170895               NaN                NaN
#
# [17 rows x 223 columns]

# %% [markdown]
# ## Plot time serie

# %%
plot_protein_phosphosites(hme1_1,
                          data_type="log2:mean",
                          proteins=["MAPK3"],
                          cell_lines=["WT"], #"BRAFS151A", "GAB1Y259A"],
                          conditions=['_EGF_'], #, '_INS_', '_EGFnINS_'],
                          legend_plot=['_EGF_'], #, 'INS', 'EGF + INS'],
                          color_palette={"_EGF_": "black",},
                                         # "BRAFS151A": "blue",
                                         # "GAB1Y259A": "green"},
                          saving_path="",
                          saving_info="",
                          title_info="",
                          fit_y_lims=False,
                          one_figure_per_site=False,
                          plot_close=False,
                          save_pdf=False,
                          save_png=False,
                          )
# Out:
# Ploting sites of protein MAPK3
# MAPK3_P27361_log2:mean_ — plot not saved

# %% [markdown]
# ## Plot dataset phosphosites

# %%
df = hme1_2.loc[hme1_2["protein_name"] == "GAB1"]

# %%
plot_dataset_phosphosites(df,
                          cluster_column="",
                          cluster_number=None,
                          data_type="log2:FC",
                          cell_lines=["WT"],
                          conditions=["_EGF_", "_INS_", "_EGFnINS_"],
                          legend_plot=["_EGF_", "_INS_", "_EGFnINS_"],
                          color_palette={"_EGF_": "red",
                                         "_INS_": "blue",
                                         "_EGFnINS_": "fuchsia"},
                          saving_path="",
                          dataset_name="",
                          saving_info="",
                          title_info="",
                          fit_y_lims=False,
                          one_figure_per_site=False,
                          plot_close=False,
                          save_pdf=False,
                          save_png=False)

# %% [markdown]
# ## Plot protein profile

# %%
plot_protein_profile(hek_1,
                     proteins = ["EGFR", "GAB1"],
                     cell_lines = ["WT"],
                     data_type="log2:FC",
                     conditions=["_EGF_", "_INS_", "_EGFnINS_"],
                     saving_path="",
                     saving_info="",
                     legend=False,
                     save_pdf=False,
                     save_png=False)

# %% [markdown]
# ## Volcano Plot

# %%
print(hme1_1.columns.values)

# %%
plot_volcano(hme1_2,
             fc_col = "WT_log2:FC_EGF_10",
             pval_col = "WT_log2:FDR_EGF_10",
             fc_thresh=0.50,
             pval_thresh=0.05,
             precomputed=False,
             title=None,
             ax=None,
             highlight_proteins=['EGFR', 'GAB1', 'BRAF'],
             match_cols=("protein_Id", "protein_name"),
             case_insensitive=True,
             fit_x_limit=False)

# %%
plot_volcano_interactive(hme1_2,
                         fc_col = "WT_log2:FC_EGF_10",
                         pval_col = "WT_log2:adjustedFDR_EGF_10",
                         site_col="site",
                         fc_thresh=0.50,
                         pval_thresh=0.05,
                         precomputed=True,
                         title=None,
                         highlight_proteins=['GAB1'],
                         match_cols=("protein_Id", "protein_name"),
                         case_insensitive=True,
                         show_highlight_labels=False)
